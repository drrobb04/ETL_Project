# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
#Extract Lower Meter CSV
Lower_Meter_path="Resources/FtUnionLower_Meters.csv"
lower_meter=pd.read_csv(Lower_Meter_path)
lower_meter.head()
# Out:
#              name           user_ref                Site_Name Product_Name  \
# 0  FT UNION LOWER     WY-BU-14-01H/V  BARRICADE UNIT 14-01 CP          GAS
# 1  FT UNION LOWER     WY-B-21-11N1MH      BARRICADE 21-11N1MH          GAS
# 2  FT UNION LOWER  WY-B-1496-S26-05V   BARRICADE 1496-S26-05V          GAS
# 3  FT UNION LOWER  WY-B-1496-S26-16V   BARRICADE 1496-S26-16V          GAS
# 4  FT UNION LOWER  WY-B-1496-S26-16V   BARRICADE 1496-S26-16V          GAS
#
#      MeterId
# 0  49037053E
# 1  49037058E
# 2  49037065E
# 3  49037074E
# 4  49037093E

# %%
#Extract Upper Meter CSV
Upper_Meter_path="Resources/FtUnionUpper_Meters.csv"
upper_meter=pd.read_csv(Upper_Meter_path)
upper_meter.head()
# Out:
#              name               user_ref               Site_Name Product_Name  \
# 0  FT UNION UPPER                  WY092        NORTH WEDGE 1-16          GAS
# 1  FT UNION UPPER                  WY092        NORTH WEDGE 1-16          GAS
# 2  FT UNION UPPER  WY-B-1595-S31-16V/11V   BARRICADE 1595-S31 CP          GAS
# 3  FT UNION UPPER      WY-B-1595-S31-11V  BARRICADE 1595-S31-11V          GAS
# 4  FT UNION UPPER      WY-B-1595-S31-16V  BARRICADE 1595-S31-16V          GAS
#
#      MeterId
# 0      17714
# 1     17714C
# 2  49037097E
# 3  49037103E
# 4  49037106E

# %%
#Extract SCADA CSV
SCADA_data_path="Resources/2020-12_FtUnion_SCADA.csv"
scada_data=pd.read_csv(SCADA_data_path)
scada_data.head()
# Out:
#      MeterId           Fac Id                            Desc        Date  \
# 0  49037065E  BARCAD_1496_05V  Barricade 1496-S26-05V All-BLM  12/31/2020
# 1  49037065E  BARCAD_1496_05V  Barricade 1496-S26-05V All-BLM  12/30/2020
# 2  49037065E  BARCAD_1496_05V  Barricade 1496-S26-05V All-BLM  12/29/2020
# 3  49037065E  BARCAD_1496_05V  Barricade 1496-S26-05V All-BLM  12/28/2020
# 4  49037065E  BARCAD_1496_05V  Barricade 1496-S26-05V All-BLM  12/27/2020
#
#       VolYdy  Casing  Tubing      Static
# 0  171.34410     NaN     NaN  191.001200
# 1  168.78860     NaN     NaN  202.324661
# 2  128.84840     NaN     NaN  176.441960
# 3   89.09632     NaN     NaN  189.576710
# 4  174.53080     NaN     NaN  116.091437

# %%
#Extract PRAMS CSV
PRAMS_data_path="Resources/2020-12_FtUnion_PRAMS_dailies.csv"
prams_data=pd.read_csv(PRAMS_data_path)
prams_data.head()
# Out:
#          Date       Site Name  Total Gas Production  Gas Sales
# 0  12/01/2020  BARRICADE 11-7                 221.0      221.0
# 1  12/02/2020  BARRICADE 11-7                 218.0      218.0
# 2  12/03/2020  BARRICADE 11-7                 221.0      221.0
# 3  12/04/2020  BARRICADE 11-7                 230.0      230.0
# 4  12/05/2020  BARRICADE 11-7                 221.0      221.0

# %%
#Extract Gas Prices CSV
Gas_prices_path="Resources/Gas_Prices_Data.csv"
gas_prices=pd.read_csv(Gas_prices_path)
gas_prices.head()
# Out:
#   Weekly U.S. Regular All Formulations Retail Gasoline Prices  \
# 0  https://www.eia.gov/dnav/pet/hist/LeafHandler....
# 1         18:00:38 GMT-0600 (Mountain Daylight Time)
# 2     Source: U.S. Energy Information Administration
# 3                                            Week of
# 4                                          5/24/2021
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Weekly U.S. Regular All Formulations Retail Ga...
# 4                                               3.02

# %%
#Transform & Join Meter CSV's - Joined the meter defining csv's
meter_combo=pd.concat([lower_meter, upper_meter])
meter_combo = meter_combo[["Site_Name", "MeterId"]]
meter_combo = meter_combo.rename(columns={"Site_Name":"Well_Name", "MeterId":"Meter_ID"})
meter_combo.head()
# Out:
#                  Well_Name   Meter_ID
# 0  BARRICADE UNIT 14-01 CP  49037053E
# 1      BARRICADE 21-11N1MH  49037058E
# 2   BARRICADE 1496-S26-05V  49037065E
# 3   BARRICADE 1496-S26-16V  49037074E
# 4   BARRICADE 1496-S26-16V  49037093E

# %%
#Transform SCADA CSV
scada_data = scada_data[["Fac Id", "Date", "VolYdy", "MeterId"]]
scada_data = scada_data.rename(columns={"Fac Id":"Well Name", "VolYdy":"Yesterdays Gas Production (Mcf)", "MeterId":"Meter ID"})
scada_data.head()
# Out:
#          Well Name        Date  Yesterdays Gas Production (Mcf)   Meter ID
# 0  BARCAD_1496_05V  12/31/2020                        171.34410  49037065E
# 1  BARCAD_1496_05V  12/30/2020                        168.78860  49037065E
# 2  BARCAD_1496_05V  12/29/2020                        128.84840  49037065E
# 3  BARCAD_1496_05V  12/28/2020                         89.09632  49037065E
# 4  BARCAD_1496_05V  12/27/2020                        174.53080  49037065E

# %%
#Transform PRAMS CSV
prams_data = prams_data[["Date", "Site Name", "Total Gas Production"]]
prams_data = prams_data.rename(columns={"Site Name":"Well Name", "Total Gas Production":"Total Gas Production (Mcf)"})
prams_data.head()
# Out:
#          Date       Well Name  Total Gas Production (Mcf)
# 0  12/01/2020  BARRICADE 11-7                       221.0
# 1  12/02/2020  BARRICADE 11-7                       218.0
# 2  12/03/2020  BARRICADE 11-7                       221.0
# 3  12/04/2020  BARRICADE 11-7                       230.0
# 4  12/05/2020  BARRICADE 11-7                       221.0

# %%
#Transform Gas Prices CSV
gas_prices = gas_prices.rename(columns={"Weekly U.S. Regular All Formulations Retail Gasoline Prices":"Week Of", "Unnamed: 1":"Avg US Gas Price ($/Gal)"})
gas_prices = gas_prices.drop([0,1,2,3])
gas_prices = gas_prices.reset_index(drop=True)

gas_prices.head()
# Out:
#      Week Of Avg US Gas Price ($/Gal)
# 0  5/24/2021                     3.02
# 1  5/17/2021                    3.028
# 2  5/10/2021                    2.961
# 3   5/3/2021                     2.89
# 4  4/26/2021                    2.872

# %%
#Create Database Connection
from config import password
engine = create_engine(f'postgresql+psycopg2://postgres:{password}@localhost/etl_project_db')
con = engine.connect()

# %%
#Load Data Frames into Database
meter_combo.to_sql(name='Meter_Combo', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_Meter_Combo"
# DETAIL:  Key ("Meter_ID")=(91591402) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-28-12b51a5407d5> in <module>
#       1 #Load Data Frames into Database
# ----> 2 meter_combo.to_sql(name='Meter_Combo', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_Meter_Combo"
# DETAIL:  Key ("Meter_ID")=(91591402) already exists.
#
# [SQL: INSERT INTO "Meter_Combo" ("Well_Name", "Meter_ID") VALUES (%(Well_Name)s, %(Meter_ID)s)]
# [parameters: ({'Well_Name': 'BARRICADE UNIT 14-01 CP', 'Meter_ID': '49037053E'}, {'Well_Name': 'BARRICADE 21-11N1MH', 'Meter_ID': '49037058E'}, {'Well_Name': 'BARRICADE 1496-S26-05V', 'Meter_ID': '49037065E'}, {'Well_Name': 'BARRICADE 1496-S26-16V', 'Meter_ID': '49037074E'}, {'Well_Name': 'BARRICADE 1496-S26-16V', 'Meter_ID': '49037093E'}, {'Well_Name': 'BARRICADE UNIT 24-36', 'Meter_ID': '49037110E'}, {'Well_Name': 'BARRICADE 22-06 CP', 'Meter_ID': '49037113E'}, {'Well_Name': 'BARRICADE 22-06-4H', 'Meter_ID': '49037114E'}  ... displaying 10 of 98 total bound parameter sets ...  {'Well_Name': 'ENDURANCE 1595-S32-29S NW1 CP', 'Meter_ID': '91591410'}, {'Well_Name': 'BARRICADE UNIT 44-1 SWD INFO ONLY', 'Meter_ID': 'ANADARKO'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
#Confirm Data Frames are in Database
